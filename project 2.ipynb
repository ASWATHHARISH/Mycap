# %%
n = int(input("Give the range for the Fibonacci numbers: "))

l = [0,1]

for i in range(n-2) :
  a = l[-1] + l[-2]
  l.append(a)

for i in l :
  print(i,end=",")
# Out:
# Give the range for the Fibonacci numbers: 7
# 0,1,1,2,3,5,8,
