# %%
import math
rad = float(input("Input the radius of the circle: "))
area = (math.pi) * (radius**2)
print("Input the radius of the circle:",rad)
print("The area of the circle with radius",rad,"is:",area)
# Out:
# Input the radius of the circle: 5
# Input the radius of the circle: 5.0
# The area of the circle with radius 5.0 is: 95.03317777109125

# %%
filename = input("Input the Filename: ")
if filename[-2:] == "py":
  ext = "python"
print("Input the Filename:",filename)
print("The extension of the file is :'"+ext+"'")
# Out:
# Input the Filename: aswath.py
# Input the Filename: aswath.py
# The extension of the file is :'python'
