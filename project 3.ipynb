# %%
num = int(input("Give the range for number of integers in list: "))
lst = []       
for i in range(0,num) :
  a = int(input("Give the interger to append in list: "))
  lst.append(a)
posnum = []           
for i in lst :
  if i > 0 :
    posnum.append(i)
print(posnum)
# Out:
# Give the range for number of integers in list: 5
# Give the interger to append in list: 3
# Give the interger to append in list: 4
# Give the interger to append in list: 5
# Give the interger to append in list: 6
# Give the interger to append in list: 7
# [3, 4, 5, 6, 7]
